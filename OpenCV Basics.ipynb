# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_file = "./labrador1.jpg"

img = cv2.imread(image_file, 0) / 255

# %%
plt.imshow(img)

# %%
# Resize image
img_width = 28
img_height = 28

dim = (img_width, img_height)

img = cv2.resize(img, dim)

plt.imshow(img)

# %%
vector = img.ravel()

vector.shape
# Out:
# (784,)
